# %%
ItRait=[52.5,
 73.33333333333333,
 39.166666666666664,
 69.16666666666667,
 54.166666666666664,
 37.5]
RRR=[50.0,
 87.5,
 37.5,
 80.0,
 50.0,
 37.5,
 47.5,
 60.0,
 52.5,
 44.0,
 8.0,
 21.5,
 11.0,
 37.0,
 16.9811320754717,
 28.30188679245283,
 15.09433962264151,
 7.547169811320755,
 64.15094339622641,
 20.0,
 10.0,
 24.0,
 16.0,
 56.0,
 40.0,
 40.0,
 30.0,
 75.0,
 31.428571428571427,
 45.714285714285715,
 42.857142857142854,
 80.0]
d=[57.5,
  72.5,
  37.5,
  50.0,
  50.0,
  37.5,
  67.5,
  50.0,
  52.5,
  50.0,
  10.0,
  18.333333333333332,
  11.0,
  26.666666666666668,
  9.433962264150944,
  9.433962264150944,
  20.754716981132077,
  3.7735849056603774,
  60.37735849056604,
  20.0,
  10.0,
  20.0,
  16.0,
  46.0,
  37.5,
  35.0,
  35.0,
  75.0,
  40.0,
  54.285714285714285,
  34.285714285714285,
  57.142857142857146]
dt=[55.0,
  52.5,
  67.5,
  65.0,
  60.0,
  50.0,
  72.5,
  55.0,
  52.5,
  38.0,
  8.0,
  14.0,
  11.0,
  26.666666666666668,
  13.20754716981132,
  11.320754716981131,
  13.20754716981132,
  5.660377358490566,
  60.37735849056604,
  20.0,
  10.0,
  20.0,
  16.0,
  44.0,
  45.0,
  37.5,
  27.5,
  57.5]
finAver=[57.916666666666664, 64.16666666666667, 47.083333333333336, 60.833333333333336, 51.25, 44.166666666666664, 55.0, 47.5, 61.25, 46.77777777777777, 8.666666666666666, 16.22222222222222, 12.222222222222223, 25.972222222222225, 16.9811320754717, 17.92452830188679, 19.49685534591195, 8.490566037735848, 51.25786163522013, 23.333333333333332, 13.733333333333334, 23.666666666666668, 23.666666666666668, 58.333333333333336, 35.833333333333336, 41.666666666666664, 23.333333333333332, 69.16666666666667, 40.0, 54.285714285714285, 34.285714285714285, 57.142857142857146]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = [10,10])
plt.title("Students forecast")
plt.plot(finAver,'b', label='average_plot', linewidth=2)
plt.plot(RRR,'r', label='real_plot', linewidth=2)
plt.ylabel('the percentage of the maximum score to the real %')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.grid(True)
plt.show()

# %%
Aversage=[59.721059972106, 57.76150627615063, 58.59832635983263, 60.01326579835987, 57.76290400385914, 58.61070911722142, 57.61547911547912, 56.518427518427515, 60.097051597051596, 53.09099321406539, 40.346391116594695, 21.395280690931525, 28.28701418877236, 32.451727328809376, 33.935851432916465, 34.063340620692717, 26.16744688940628, 29.78798536191246, 44.36491849246708, 29.477396021699818, 35.711754068716099, 28.06618444846293, 31.259493670886076, 50.047197106690774, 48.915821033210335, 51.40659594095941, 39.81872693726937, 55.31988007380073, 46.49886621315192, 47.30839002267573, 50.385487528344676, 60.51473922902494]

# %%
import numpy as np
import matplotlib.pyplot as plt
 
plt.ioff()
x = np.arange(32)
y1 = Aversage
y2 = RRR

fig, ax = plt.subplots()
 
ax.plot(x, y1, 'rx', x, y2, 'b+', linestyle='solid')
ax.fill_between(x, y1, y2, where=y2>y1, interpolate=True,
                color='green', alpha=0.3)
 
lgnd = ax.legend(['Average', 'y2'], loc='upper center', shadow=True)
lgnd.get_frame().set_facecolor('#ffb19a')
plt.grid(True)
 
plt.show()

# %%

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.grid(True)
plt.show()

# %%
RRR=[50.0,87.5,37.5,80.0,50.0,37.5,47.5,60.0,52.5,44.0,8.0,21.5,11.0,37.0,16.9811320754717,28.30188679245283,15.09433962264151,7.547169811320755,64.15094339622641,20.0,10.0,24.0,16.0,56.0,40.0,40.0,30.0,75.0,31.428571428571427,45.714285714285715,42.857142857142854,80.0]
OneK=[57.5, 72.5, 37.5, 50.0, 50.0, 37.5, 67.5, 50.0, 52.5, 70.0, 20.0, 15.0, 12.5, 40.0, 9.433962264150944, 9.433962264150944, 20.754716981132077, 3.7735849056603774, 60.37735849056604, 20.0, 10.0, 20.0, 16.0, 46.0, 37.5, 35.0, 35.0, 75.0, 40.0, 54.285714285714285, 34.285714285714285, 57.142857142857146]
TwoK=[67.5, 71.25, 51.25, 50.0, 52.5, 37.5, 60.0, 50.0, 63.75, 63.75, 20.0, 15.0, 12.5, 40.0, 9.433962264150944, 16.037735849056602, 20.754716981132077, 6.60377358490566, 51.88679245283019, 25.0, 15.0, 25.0, 28.0, 58.0, 35.0, 37.5, 18.75, 68.75, 40.0, 54.285714285714285, 34.285714285714285, 57.142857142857146]
SeventyK=[65.82142857142857, 65.60714285714286, 41.392857142857146, 64.96428571428571, 61.57142857142857, 42.5, 55.93283582089552, 55.1865671641791, 59.88805970149254, 52.02205882352941, 21.654411764705884, 17.334558823529413, 15.183823529411764, 42.150735294117645, 21.293800539083552, 21.20395327942498, 20.681042228212036, 10.819107517220719, 50.673854447439375, 23.476190476190474, 13.307936507936507, 23.857142857142858, 26.126984126984127, 56.333333333333336, 33.9375, 40.416666666666664, 31.416666666666668, 65.33333333333333, 38.73015873015873, 42.857142857142854, 41.58730158730159, 70.15873015873017]

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(OneK,'b', label='average_plot', linewidth=2)
plt.title('k=1')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(TwoK,'b', label='average_plot', linewidth=2)
plt.title('k=2')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(finAver,'b', label='average_plot', linewidth=2)
plt.title('k=6')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(SeventyK,'b', label='average_plot', linewidth=2)
plt.title('k=70')
plt.grid(True)

# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=1.92, bottom=0.08, left=0.10, right=2.95, hspace=0.15,
                    wspace=0.005)

plt.show()

# %%
HandrK=[66.5, 64.9, 41.475, 65.5, 62.125, 43.475, 56.640625, 55.442708333333336, 61.953125, 54.26546391752577, 22.487113402061855, 17.667525773195877, 15.608247422680412, 43.69845360824742, 21.433114267542933, 21.96311214755142, 21.20076319694721, 11.432054271782905, 51.515793936824274, 23.786516853932586, 13.64494382022472, 24.213483146067414, 26.9438202247191, 57.57303370786517, 34.05882352941177, 40.78823529411765, 32.42941176470588, 66.98529411764706, 38.18181818181818, 43.37662337662337, 41.81818181818181, 68.31168831168831]
TwoHandrK=[63.7375, 61.625, 48.825, 63.0125, 59.8375, 48.0, 56.979166666666664, 54.9609375, 62.6171875, 52.12158469945355, 23.691256830601095, 19.098360655737704, 22.1051912568306, 42.94398907103825, 22.06365213619608, 22.348731294730026, 20.96898720451096, 11.485903274777709, 52.43797440902196, 24.34640522875817, 13.88888888888889, 24.68235294117647, 27.758169934640524, 58.673202614379086, 35.74829931972789, 43.994897959183675, 31.642857142857142, 64.74489795918367, 40.50420168067227, 44.201680672268914, 44.87394957983194, 72.43697478991596]
ThousAver=[61.73, 59.805, 53.215, 60.95691382765531, 57.635270541082164, 51.3376753507014, 55.34446764091858, 53.78914405010438, 59.217118997912316, 47.954383886255926, 24.80983412322275, 20.84537914691943, 26.223933649289098, 43.44549763033175, 22.447714258894273, 22.62550455270821, 20.912278231484112, 11.593119309114819, 50.341312306392574, 24.48993288590604, 14.285906040268456, 24.8758389261745, 28.251677852348994, 59.21208053691275, 36.164089347079035, 46.59965635738832, 30.087628865979383, 61.486254295532646, 39.45054945054945, 43.84615384615385, 49.01098901098901, 71.97802197802197]
THHH=[60.6475, 59.155, 55.2025, 59.50753768844221, 56.814070351758794, 52.0, 54.690803382663844, 53.356236786469346, 57.167019027484145, 47.62627551020408, 25.734375, 21.616390306122447, 28.979591836734695, 43.504464285714285, 22.955232470847346, 23.237700815775014, 21.414919173214603, 11.879535558780859, 50.60965417146285, 24.884972170686456, 14.82857142857143, 25.388868274582556, 29.630797773654916, 61.217439703153985, 36.964285714285715, 48.13956766917293, 29.908364661654137, 60.33552631578947, 40.730897009966775, 43.98671096345514, 49.23588039867108, 71.69435215946841]

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(HandrK,'b', label='average_plot', linewidth=2)
plt.title('k=100')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(TwoHandrK,'b', label='average_plot', linewidth=2)
plt.title('k=200')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(ThousAver,'b', label='average_plot', linewidth=2)
plt.title('k=500')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(RRR, 'r', label='average_plot', linewidth=2)
plt.plot(THHH,'b', label='average_plot', linewidth=2)
plt.title('k=1000')
plt.grid(True)

# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=1.92, bottom=0.08, left=0.10, right=2.95, hspace=0.15,
                    wspace=0.005)

plt.show()

# %%
ballsOnPredm=np.array([[60.6475, 59.155, 55.2025], [59.50753768844221, 56.814070351758794, 52.0], [54.690803382663844, 53.356236786469346, 57.167019027484145], [47.62627551020408, 25.734375, 21.616390306122447], [28.979591836734695, 43.504464285714285, 22.955232470847346], [23.237700815775014, 21.414919173214603, 11.879535558780859], [50.60965417146285, 24.884972170686456, 14.82857142857143], [25.388868274582556, 29.630797773654916, 61.217439703153985], [36.964285714285715, 48.13956766917293, 29.908364661654137], [60.33552631578947, 40.730897009966775, 43.98671096345514]])

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 10

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('b', 'o', -5, -2)]:
    ax.scatter(ballsOnPredm[:,0], ballsOnPredm[:,1], ballsOnPredm[:,2], c=c, marker=m)

ax.scatter(40, 40, 40, c='r', marker='^')    
    
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
crot_test=[80.0, 81.78571428571429, 85.35714285714286, 75.0, 69.64285714285714, 77.5, 66.07142857142857, 67.5, 73.57142857142857, 68.54166666666667, 29.583333333333332, 21.458333333333332, 36.666666666666664, 44.583333333333336, 25.786163522012583, 25.786163522012583, 26.257861635220124, 13.836477987421382, 74.84276729559748, 27.833333333333332, 18.166666666666668, 27.666666666666668, 36.0, 69.33333333333333, 41.458333333333336, 51.5, 29.375, 86.04166666666667]

# %%
#Градиентный спсук
import matplotlib.pyplot as plt
plt.figure(figsize = [10,10])
plt.title("Students forecast")
#plt.plot(finAver,'g', label='average_plot', linewidth=2)
plt.plot(crot_test,'r', label='real_plot', linewidth=2)
plt.ylabel('the percentage of the maximum score to the real %')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.grid(True)
plt.show()
